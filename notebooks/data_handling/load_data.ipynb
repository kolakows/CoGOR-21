# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive/MyDrive/bhl
# Out:
# Mounted at /gdrive
# /gdrive/MyDrive/bhl

# %%
import pandas as pd

# pewnie musicie lokalnie sobie wrzucić pod bhl/uneven/
train = pd.read_csv('./uneven/train.csv')
test = pd.read_csv('./uneven/test.csv')

# %%
cols_to_drop = ['void()', 'subject']

train = train.drop(cols_to_drop, axis = 1)
test = test.drop(cols_to_drop, axis = 1)

# %%
target = ['Activity']

train_x, train_y = train.drop(target, axis = 1), train[target]
test_x, test_y = test.drop(target, axis = 1), test[target]
